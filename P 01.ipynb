# %% [markdown]
# # **Practice 01: Basics of OOP in Python** 👀

# %% [markdown]
# #### Contents: ####
# - Basic Concepts in OOP
#     - **[Class](#cls)**
#         - [Class Definition](#classdefinition)
#         - [Empty Class](#empty)
#         - [Class Object](#classobject)
#         - *[Exercise 1](#ex1)*
#     - **[Instances (Objects)](#instance)**
#         - *[Exercise 2](#ex2)*
#     - **[Methods](#method)**
#         - *[Exercise 3](#ex3)*
#     - **[Class Objects vs. Instance Object](#vs)**
#     - [Home Exercises](#hw)
#     - [Exercises Solutions](#sol)

# %% [markdown]
# <pre>
# ╔═ 💡 <b>TIP</b>
# ║  <i>In Exercises, when time permits, try to write the codes yourself, and do not copy it from the other cells.
# ║  Making mistakes and finding the mistakes is the best way to learn a new syntax.</i>
# ╚══════════════════════════════════════════════════
# </pre>

# %% [markdown]
# <br><br><a id='cls'></a>
# ## ▛▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▜
# ## ▙▁ **🄲LASS**

# %% [markdown]
# Classes provide a means of bundling <u>*data*</u> and <u>*functionality*</u> together.<br>
# - Creating a new class creates a new type of **object**, allowing new **instances** of that type to be made. <br>
# - Class instances can have **attributes** attached to it for *maintaining* its *state*. <br>
# - Class instances</u> can also have **methods** (defined by its class) for *modifying* its *state*.

# %% [markdown]
# <a id='classdefinition'></a>
# #### **▇▂ Class Definition ▂▂**
# The simplest form of class definition looks like this:
#
# ```Python
# class ClassName:
#     '''This is a docstring. You can provide information about the class.'''
#     <statement-1>
#     .
#     .
#     .
#     <statement-N>
# ```
#
# ▚ Class definitions, like function definitions (*def* statements) <u>must be executed</u> before they have any effect.
#
# A class creates a new *local namespace*, where all its attributes are defined. Attributes may be <u>*data*</u> or <u>*functions*</u>.

# %% [markdown]
# <a id='empty'></a>
# #### **▇▂ Empty Class ▂▂**
# You can create an "empty" class -- like a blank template -- by including the `pass` statement after the class declaration.

# %%
# define an empty class

class EmptyClass:
    '''This is an empty class.'''
    pass

# %% [markdown]
# <a id='classobject'></a>
# #### **▇▂ Class Object ▂▂**
#
# As soon as we define a class, a new <u>*class object*</u> is created with the same name. <br>

# %%
print(EmptyClass)

# %% [markdown]
# This **class object** allows us to access the different attributes as well as to <u>instantiate</u> new objects of that class.<br>
#
# Class objects support two kinds of operations:
# - *attribute references*
# - *instantiation*
#
# Attribute references use the standard syntax used for all attribute references in Python: `obj.name`<br>
# ▚ Valid attribute names are all the names that were in the <u>class’s namespace</u> when the class object was created.

# %%
class dog:
    '''This is a class defined for Dogs.
       more information about the class could be added here.'''
    
    # Class Attributes
    species = 'mammal'

# %%
print(dog.species)

# %% [markdown]
# You can get information about the class using `help` function.

# %%
help(dog)

# %% [markdown]
# Try the following class defined for eagles:

# %%
class eagle:
    pass

# %%
eagle.species = 'bird'

# %%
print(eagle.species)

# %% [markdown]
# <br><br><a id='ex1'></a>
# ◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾

# %% [markdown]
# **✎ Exercise 𝟙** <br>

# %% [markdown]
# ❶ Define a new class for crocodiles and assign 'reptiles" as its `species`.<br>

# %%
# Exercise 1.1

# %% [markdown]
# ❷ Print the class object. <br>

# %%
# Exercise 1.2

# %% [markdown]
# ❸ Print the `species` of the class.

# %%
# Exercise 1.3

# %% [markdown]
# ◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾

# %% [markdown]
# <br><br><a id='instance'></a>
# ## ▛▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▜
# ## **▙▁ Declaring 🄸NSTANCE / 🄾BJECT**

# %% [markdown]
# We saw that when a class definition is left normally (via the end), a <u>class object</u> is created.It can be used to create new object instances (**instantiation**) of that class.<br>
# A class is like a blueprint while an instance is a copy of the class with actual values. An **instance** of a Class is also called as an **object**.<br>
# The procedure to create an object is similar to a *function call*. For example, the code below creates a new instance of the class and assigns this object to a local variable.

# %%
class dog:
    species = 'mammal'

Cooper = dog()

# %% [markdown]
# We can access the attributes of objects using the object name prefix.

# %%
print(Cooper.species)

# %% [markdown]
# <br><br><a id='ex2'></a>
# ◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾

# %% [markdown]
# **✎ Exercise 𝟚** <br>

# %% [markdown]
# ❶ Run the following code. Why you get an error?<br>

# %%
class eagle:
    pass

Goldie = eagle()
print(Goldie.species)

# %% [markdown]
# ❷ Fix the error. For your convenient, the code is copied to the cell below.

# %%
# Exercise 2.2

class eagle:
    pass

Goldie = eagle()
print(Goldie.species)

# %% [markdown]
# ❸ Add more attributes to the class, without manipulating the class defintion.<br>

# %%
# Exercise 2.3

# %% [markdown]
# ❹ Define a instance for the class and print the attributes of the instance.

# %%
# Exercise 2.4

# %% [markdown]
# ◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾

# %% [markdown]
# <br><br><a id='method'></a>
# ## ▛▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▜
# ## **▙▁ 🄼ETHOD**

# %% [markdown]
# A function inside a class is called a `Method`.

# %%
class dog:
    # Class Attributes
    species = 'mammal'
    
    # Class method
    def can():
        print('bark')

class eagle:
    # Class Attributes
    species = 'bird'
    
    def can():
        print('fly')

# %% [markdown]
# You can try the method, simply by calling it with dog class object:

# %%
dog.can()

# %% [markdown]
# Now, let's create an object (instance), and call the method.<br>
# **What is the output?<br>
# Why?**

# %%
Lexi = dog()

# %%
Lexi.can()

# %% [markdown]
# Now, try the following code:

# %%
class dog:
    # Class Attributes
    species = 'mammal'
    
    # Class method
    def can():
        print('bark')
    
    # instance method
    def describe(self):
        print('The dog  is a domesticated carnivore of the family Canidae.')
        print(' It is part of the wolf-like canids, and is the most widely abundant terrestrial carnivore.')

# Another similar class
class eagle:
    species = 'bird'
    
    def can():
        print('fly')
    
    def describe(self):
        print('Eagle is the common name for many large birds of prey of the family Accipitridae.')
        print('Eagles belong to several groups of genera, not all of which are closely related.')        
        print('Most of the 60 species of eagle are from Eurasia and Africa. ')

# %% [markdown]
# **⚠ Important:** <br>
# Call the methods, using the **class object** and an **instance object**, as below, and analyze your observation.

# %%
Lexi = dog()

# %%
Lexi.describe()

# %%
Lexi.can()

# %%
dog.describe()

# %%
dog.can()

# %%
dog.describe(Lexi)

# %% [markdown]
# <pre>
# ╔═ ⚠ <b>NOTE</b>
# ║  <i><b>self</b> is used to pass the (instance) object as an argument to the class.
# ║  When you call a method using an object, it automatically pass the object name to the method as <b>the first argument</b>.</i>
# ╚══════════════════════════════════════════════════
# </pre>

# %% [markdown]
# <br><br><a id='ex3'></a>
# ◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾

# %% [markdown]
# **✎ Exercise 𝟛** <br>
# Repeat the same practice with the class `eagle`.<br>

# %%
Goldie = eagle()

# %% [markdown]
# ❶ call `describe` method with the correct object (**class object** or **instance object**?).<br>

# %% [markdown]
# ❷ call `can` method with the correct object.<br>

# %% [markdown]
# ◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾◾

# %% [markdown]
# <br><br><a id='vs'></a>
# ## ▛▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▔▜
# ## **▙▁ 🄲LASS OBJECT** vs. **🄸NSTANCE OBJECT**

# %% [markdown]
# Let's have a deeper look at the concepts of class object and instance object.<br>

# %%
class cat:
    # Class Attributes
    species = 'mammal'

    def print_name(name):
        print(name)

c = cat()

# %%
print(id(cat))
print(id(c))

# %%
print(cat.species)
print(c.species)

# %% [markdown]
# **⚠ Conclusion 1** <br>
# Class attribute is same for both the class object and the instance object.

# %%
c.species = 'mammal (instance)'

# %%
print(cat.species)
print(c.species)

# %% [markdown]
# **⚠ Conclusion 2** <br>
# Changing the attribute of the instance object <u>will not</u> affect the class object.

# %%
class cat:
    # Class Attributes
    species = 'mammal'

    def print_name(name):
        print(name)

c = cat()

# %%
cat.species = 'mammal (class)'

# %%
print(cat.species)
print(c.species)

# %% [markdown]
# **⚠ Conclusion 3** <br>
# Changing the attribute of the class object will affect the instance object.

# %% [markdown]
# #### Methods
# How about the method?

# %%
class cat:
    # Class Attributes
    species = 'mammal'

    def print_name(name):
        print(name)

c = cat()

# %%
cat.print_name('daisy')

# %%
c.print_name('daisy')

# %%
c.print_name()

# %% [markdown]
# So, how should we define attributes and methods for the instance objects?

# %% [markdown]
# ### Define Attributes for Instances

# %% [markdown]
# This method is autoatically called everytime you create an instance of the class.

# %%
class dog:
    # Class Attributes
    species = 'mammal'

# %%
d1 = dog()
d1.name = 'Cooper'
d1.y_birth = 2018

# %%
d2 = dog()
d2.name = 'Daisy'

# %%
print(d1.name, 'is born on', d1.y_birth)
print(d2.name, 'is born on', d2.y_birth)

# %% [markdown]
# 🔴 Why you got an error?

# %%
dir(d1)

# %%
dir(d2)

# %% [markdown]
# <br><br><a id='sol'></a>
# ◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼

# %% [markdown]
# #### 🔑 **Exercises Solutions** ####

# %% [markdown]
# **Exercise 1.1:**

# %%
class crocodile:
    '''crocodile class '''
    species = 'reptiles'

# %% [markdown]
# **Exercise 1.2:**

# %%
print(crocodile)

# %% [markdown]
# **Exercise 1.3:**

# %%
print(crocodile.species)

# %% [markdown]
# **Exercise 2.2:**

# %%
class eagle:
    pass

eagle.species = 'bird'  # You may define the attributes inside the body of the class (next cell).

Goldie = eagle()
print(Goldie.species)

# %%
class eagle:
    species = 'bird'

Goldie = eagle()
print(Goldie.species)

# %% [markdown]
# **⚠ Note:** <br>
# If you define attribute in the body of the class, you must remove the class name (`species = 'bird'`, not `eagle.species = 'bird'`)

# %% [markdown]
# **Exercise 2.3:**

# %%
eagle.lifespan = 20
eagle.wingspan = 2.2

# %% [markdown]
# **Exercise 2.4:**

# %%
myEagle = eagle()

print(myEagle.species)
print(myEagle.lifespan)
print(myEagle.wingspan)

# %% [markdown]
# **Exercise 3.1:**

# %%
Goldie.describe()

# %%
# This is also correct
eagle.describe(Goldie)

# %% [markdown]
# **Exercise 3.2:**

# %%
eagle.can()
